# %%
import keras

from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Convolution2D, MaxPooling2D

# %%
classifier = Sequential()

classifier.add(Convolution2D(32,3,3, input_shape = (64,64,3), activation='relu'))

classifier.add(MaxPooling2D(pool_size = (2,2)))

classifier.add(Flatten())

classifier.add(Dense(output_dim = 128, activation = 'relu'))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(64, 64, 3..., activation="relu")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
#   if __name__ == '__main__':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`
#   # Remove the CWD from sys.path while we load stuff.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    'food41/images/waffles',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)

test_set = train_datagen.flow_from_directory(
    'food41/images/waffles',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
from IPython.display import display
from PIL import Image

classifier.fit_generator(
    training_set,
    steps_per_epoch=8000,
    epochs=5,
    validation_data=test_set,
    validation_steps=800
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-36-4778a481d8bc> in <module>
#       7     epochs=5,
#       8     validation_data=test_set,
# ----> 9     validation_steps=800
#      10 )
#
# /anaconda3/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
# ...

# %%
import json
def readJSON(file):
    with open(file) as f:
        return json.load(f)

# %%
train = readJSON('food41/meta/train.json')
test = readJSON('food41/meta/test.json')

# %%
from PIL import Image as img
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
def loadImage(file):
    return np.array([np.array(img.open("food41/images/"+i+'.jpg')) for i in file])
#     for i in file:
#         tmp.append(img_to_array(img.open(paths+'/food41/images/'+i+'.jpg')))
#     return tmp

# x = np.array([np.array(Image.open(fname)) for fname in filelist])

# %%
from PIL import Image
import numpy as np
import os

mypath=os.path.dirname('food41/images/waffles/')
def load_dataset():
    data =[]
    for fname in os.listdir(mypath):
        pathname = os.path.join(mypath, fname)
        img = Image.open(pathname)
        img1 = img[np.newaxis,:,:]
        data.append(img1)
    return data

data= load_dataset()
data_x=np.array(data)
print(data_x.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-7f2e831acd2f> in <module>
#      13     return data
#      14
# ---> 15 data= load_dataset()
#      16 data_x=np.array(data)
#      17 print(data_x.shape)
#
# <ipython-input-23-7f2e831acd2f> in load_dataset()
#       9         pathname = os.path.join(mypath, fname)
#      10         img = Image.open(pathname)
# ---> 11         img1 = img[np.newaxis,:,:]
#      12         data.append(img1)
#      13     return data
#
# TypeError: 'JpegImageFile' object is not subscriptable

# %%
omelette_train = loadImage(train.get('omelette'))
omelette_test = loadImage(test.get('omelette'))
hot_dog_train = loadImage(train.get('hot_dog'))
hot_dog_test = loadImage(test.get('hot_dog'))

# print(omelette_train.shape)

# omelette_train = np.array(omelette_train)
# omelette_test = np.array(omelette_test)
# hot_dog_train = np.array(hot_dog_train)
# hot_dog_test = np.array(hot_dog_test)

# omelette_train = omelette_train.reshape(750,384)
# omelette_test = omelette_test.reshape(250,384)
# hot_dog_train = hot_dog_train.reshape(750,384)
# hot_dog_test = hot_dog_test.reshape(250,384)

# convert class vectors to binary class matrices
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
batch_size = 128
num_classes = 10
epochs = 12

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(384,512,3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# print(len(omelette_train[0][0][0]))
print(omelette_train.shape)
print(omelette_train)
# 750 x 384 x 512 x 3
# Out:
# (750,)
# [array([[[ 19,  17,   2],
#         [ 19,  17,   2],
#         [ 19,  17,   2],
#         ...,
#         [230, 244, 227],
#         [232, 246, 229],
#         [230, 244, 227]],
#
#        [[ 18,  16,   1],
#         [ 18,  16,   1],
#         [ 18,  16,   1],
#         ...,
#         [223, 237, 220],
#         [233, 247, 230],
#         [241, 255, 238]],
#
#        [[ 18,  16,   1],
#         [ 18,  16,   1],
#         [ 18,  16,   1],
#         ...,
#         [227, 241, 224],
#         [229, 243, 226],
#         [236, 250, 235]],
#
#        ...,
#
#        [[  0,   2,   0],
#         [  0,   2,   0],
#         [  0,   2,   0],
#         ...,
#         [  0,   2,   0],
#         [  0,   2,   0],
#         [  0,   2,   0]],
#
#        [[  0,   2,   0],
#         [  0,   2,   0],
#         [  0,   2,   0],
#         ...,
#         [  0,   2,   0],
#         [  0,   2,   0],
#         [  0,   2,   0]],
#
#        [[  0,   2,   0],
#         [  0,   2,   0],
# ...

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(omelette_train, hot_dog_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(omelette_test, hot_dog_test))
score = model.evaluate(omelette_test, hot_dog_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-17fb176980e7> in <module>
#       7           epochs=epochs,
#       8           verbose=1,
# ----> 9           validation_data=(omelette_test, hot_dog_test))
#      10 score = model.evaluate(omelette_test, hot_dog_test, verbose=0)
#      11 print('Test loss:', score[0])
#
# /anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ...
